# %% [markdown]
# # Initializing from colab
# Upload this file on colab and run this, then use the files inside that folder

# %%
# !git clone https://github.com/elenanespolo/Sentiment_Sarcasm_Analysis

# %cd Sentiment_Sarcasm_Analysis
# !git pull
